# %%
import pandas as pd
import sqlite3
import datetime
# Create connection to database
con = sqlite3.connect("dublinBikes.db")
cur = con.cursor()

# Select all data
cur.execute("SELECT * From dublinBikes")

# Store all fetched data in a list
data = cur.fetchall()
con.close()

# %%
# Create a pandas dataframe from this list
df = pd.DataFrame(data)
df.head(5)
# Out:
#                         0   1   2   3   4   5       6              7   \
# 0         Smithfield North  30   0   1  30   0  Dublin  1459511200000
# 1     Parnell Square North  19   1   1  20   0  Dublin  1459511455000
# 2            Pearse Street   0  30   1  30   0  Dublin  1459511756000
# 3              Excise Walk  11  29   0  40   0  Dublin  1459511555000
# 4  Fitzwilliam Square West   7  23   0  30   0  Dublin  1459511770000
#
#                         8   9          10        11    12
# 0         SMITHFIELD NORTH  42  53.349562 -6.278198  OPEN
# 1     PARNELL SQUARE NORTH  30  53.353462 -6.265305  OPEN
# 2            PEARSE STREET  32  53.344304 -6.250427  OPEN
# 3              EXCISE WALK  48  53.347777 -6.244239  OPEN
# 4  FITZWILLIAM SQUARE WEST  13  53.336074 -6.252825  OPEN

# %%
# Rename the column headers for clarity
df.columns=["address","available_bike_stands","available_bikes","banking","bike_stands","bonus","contract_name",\
            "last_update","name","number","position_lat","position_lng","status"]
df.head(10)
# Out:
#                         address  available_bike_stands  available_bikes  \
# 0              Smithfield North                     30                0
# 1          Parnell Square North                     19                1
# 2                 Pearse Street                      0               30
# 3                   Excise Walk                     11               29
# 4       Fitzwilliam Square West                      7               23
# 5  St. James Hospital (Central)                     27               12
# 6                  Hanover Quay                      0               40
# 7            Oliver Bond Street                     26                4
# 8       Collins Barracks Museum                     38                0
# 9               Brookfield Road                     30                0
#
#    banking  bike_stands  bonus contract_name    last_update  \
# 0        1           30      0        Dublin  1459511200000
# 1        1           20      0        Dublin  1459511455000
# 2        1           30      0        Dublin  1459511756000
# 3        0           40      0        Dublin  1459511555000
# 4        0           30      0        Dublin  1459511770000
# 5        0           40      0        Dublin  1459511613000
# 6        1           40      0        Dublin  1459511538000
# 7        0           30      0        Dublin  1459511608000
# 8        1           38      0        Dublin  1459511480000
# 9        0           30      0        Dublin  1459511299000
#
#                            name  number  position_lat  position_lng status
# 0              SMITHFIELD NORTH      42     53.349562     -6.278198   OPEN
# 1          PARNELL SQUARE NORTH      30     53.353462     -6.265305   OPEN
# 2                 PEARSE STREET      32     53.344304     -6.250427   OPEN
# 3                   EXCISE WALK      48     53.347777     -6.244239   OPEN
# 4       FITZWILLIAM SQUARE WEST      13     53.336074     -6.252825   OPEN
# 5  ST. JAMES HOSPITAL (CENTRAL)      81     53.339983     -6.295594   OPEN
# 6                  HANOVER QUAY      68     53.344115     -6.237153   OPEN
# 7            OLIVER BOND STREET      74     53.343893     -6.280531   OPEN
# 8       COLLINS BARRACKS MUSEUM      87     53.347477     -6.285250   OPEN
# 9               BROOKFIELD ROAD      84     53.339005     -6.300217   OPEN

# %%
# Convert to seconds
df["new_time"] = df["last_update"]/1000

# %%
print(datetime.datetime.fromtimestamp(1459511200))
# Out:
# 2016-04-01 12:46:40

# %%
df['datetime'] = pd.to_datetime(df['new_time'],unit='s')

# %%
x = df["datetime"][0]
print(x.strftime('%H:%M:%S'))
# Out:
# 11:46:40

# %%
print(x.strftime('%A'))
# Out:
# Friday

# %%
df2 = df[["new_time", "datetime"]]

# %%
df2.head()
# Out:
#        new_time            datetime
# 0  1.459511e+09 2016-04-01 11:46:40
# 1  1.459511e+09 2016-04-01 11:50:55
# 2  1.459512e+09 2016-04-01 11:55:56
# 3  1.459512e+09 2016-04-01 11:52:35
# 4  1.459512e+09 2016-04-01 11:56:10

# %%
f = open("test.txt", "w")
for i in df["datetime"]:
    f.write(str(i)+"\n")
f.close()

# %%
f=open("test2.txt", "r")
data = f.readlines()
f.close()

# %%
df3 = pd.DataFrame(data)
df3.head()
# Out:
#                        0
# 0  2016-04-01 11:46:40\n
# 1  2016-04-01 11:50:55\n
# 2  2016-04-01 11:55:56\n
# 3  2016-04-01 11:52:35\n
# 4  2016-04-01 11:56:10\n

# %%
df["datetime"] = df3[0]
df.head()
# Out:
#                    address  available_bike_stands  available_bikes  banking  \
# 0         Smithfield North                     30                0        1
# 1     Parnell Square North                     19                1        1
# 2            Pearse Street                      0               30        1
# 3              Excise Walk                     11               29        0
# 4  Fitzwilliam Square West                      7               23        0
#
#    bike_stands  bonus contract_name    last_update                     name  \
# 0           30      0        Dublin  1459511200000         SMITHFIELD NORTH
# 1           20      0        Dublin  1459511455000     PARNELL SQUARE NORTH
# 2           30      0        Dublin  1459511756000            PEARSE STREET
# 3           40      0        Dublin  1459511555000              EXCISE WALK
# 4           30      0        Dublin  1459511770000  FITZWILLIAM SQUARE WEST
#
#    number  position_lat  position_lng status      new_time  \
# 0      42     53.349562     -6.278198   OPEN  1.459511e+09
# 1      30     53.353462     -6.265305   OPEN  1.459511e+09
# 2      32     53.344304     -6.250427   OPEN  1.459512e+09
# 3      48     53.347777     -6.244239   OPEN  1.459512e+09
# 4      13     53.336074     -6.252825   OPEN  1.459512e+09
#
#                 datetime
# 0  2016-04-01 11:46:40\n
# 1  2016-04-01 11:50:55\n
# 2  2016-04-01 11:55:56\n
# 3  2016-04-01 11:52:35\n
# 4  2016-04-01 11:56:10\n

# %%
df["datetime"] = df["datetime"].str.replace("\n", "")

# %%
df.head()
# Out:
#                    address  available_bike_stands  available_bikes  banking  \
# 0         Smithfield North                     30                0        1
# 1     Parnell Square North                     19                1        1
# 2            Pearse Street                      0               30        1
# 3              Excise Walk                     11               29        0
# 4  Fitzwilliam Square West                      7               23        0
#
#    bike_stands  bonus contract_name    last_update                     name  \
# 0           30      0        Dublin  1459511200000         SMITHFIELD NORTH
# 1           20      0        Dublin  1459511455000     PARNELL SQUARE NORTH
# 2           30      0        Dublin  1459511756000            PEARSE STREET
# 3           40      0        Dublin  1459511555000              EXCISE WALK
# 4           30      0        Dublin  1459511770000  FITZWILLIAM SQUARE WEST
#
#    number  position_lat  position_lng status      new_time    datetime  \
# 0      42     53.349562     -6.278198   OPEN  1.459511e+09  2016-04-01
# 1      30     53.353462     -6.265305   OPEN  1.459511e+09  2016-04-01
# 2      32     53.344304     -6.250427   OPEN  1.459512e+09  2016-04-01
# 3      48     53.347777     -6.244239   OPEN  1.459512e+09  2016-04-01
# 4      13     53.336074     -6.252825   OPEN  1.459512e+09  2016-04-01
#
#        time
# 0  11:46:40
# 1  11:50:55
# 2  11:55:56
# 3  11:52:35
# 4  11:56:10

# %%
df.replace(to_replace="2016-04-01", value="Friday", inplace=True)

# %%
df_temp = df["time"].str.split(":", expand=True)

# %%
df.head()
# Out:
#                    address  available_bike_stands  available_bikes  banking  \
# 0         Smithfield North                     30                0        1
# 1     Parnell Square North                     19                1        1
# 2            Pearse Street                      0               30        1
# 3              Excise Walk                     11               29        0
# 4  Fitzwilliam Square West                      7               23        0
#
#    bike_stands  bonus contract_name    last_update                     name  \
# 0           30      0        Dublin  1459511200000         SMITHFIELD NORTH
# 1           20      0        Dublin  1459511455000     PARNELL SQUARE NORTH
# 2           30      0        Dublin  1459511756000            PEARSE STREET
# 3           40      0        Dublin  1459511555000              EXCISE WALK
# 4           30      0        Dublin  1459511770000  FITZWILLIAM SQUARE WEST
#
#    number  position_lat  position_lng status      new_time datetime      time  \
# 0      42     53.349562     -6.278198   OPEN  1.459511e+09   Friday  11:46:40
# 1      30     53.353462     -6.265305   OPEN  1.459511e+09   Friday  11:50:55
# 2      32     53.344304     -6.250427   OPEN  1.459512e+09   Friday  11:55:56
# 3      48     53.347777     -6.244239   OPEN  1.459512e+09   Friday  11:52:35
# 4      13     53.336074     -6.252825   OPEN  1.459512e+09   Friday  11:56:10
#
#   Hour
# 0   11
# 1   11
# 2   11
# 3   11
# 4   11

# %%
con = sqlite3.connect("test2.db")
cur= con.cursor()
df.to_sql("dBikes", con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-284-c3a343d82673> in <module>()
#       1 con = sqlite3.connect("test2.db")
#       2 cur= con.cursor()
# ----> 3 df.to_sql("dBikes", con)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1158         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1159                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1160                    chunksize=chunksize, dtype=dtype)
#    1161
#    1162     def to_pickle(self, path):
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     569     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     570                       index_label=index_label, schema=schema,
# --> 571                       chunksize=chunksize, dtype=dtype)
#     572
#     573
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1655                             if_exists=if_exists, index_label=index_label,
#    1656                             dtype=dtype)
# -> 1657         table.create()
#    1658         table.insert(chunksize)
#    1659
#
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     690         if self.exists():
#     691             if self.if_exists == 'fail':
# --> 692                 raise ValueError("Table '%s' already exists." % self.name)
#     693             elif self.if_exists == 'replace':
#     694                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'dBikes' already exists.

# %%
con.close()
con = sqlite3.connect("test.db")
con.close()
