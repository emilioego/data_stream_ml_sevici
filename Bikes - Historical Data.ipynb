# %%
import pandas as pd
import sqlite3
import datetime
# Create connection to database
con = sqlite3.connect("dublinBikes.db")
cur = con.cursor()

# Select all data
cur.execute("SELECT * From dublinBikes")

# Store all fetched data in a list
data = cur.fetchall()
con.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-5c5de28ec7fc> in <module>
#       7
#       8 # Select all data
# ----> 9 cur.execute("SELECT * From dublinBikes")
#      10
#      11 # Store all fetched data in a list
#
# OperationalError: no such table: dublinBikes

# %%
# Create a pandas dataframe from this list
df = pd.DataFrame(data)
df.head(5)

# %%
# Rename the column headers for clarity
df.columns=["address","available_bike_stands","available_bikes","banking","bike_stands","bonus","contract_name",\
            "last_update","name","number","position_lat","position_lng","status"]
df.head(10)

# %%
# Convert to seconds
df["new_time"] = df["last_update"]/1000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a845f4df99ff> in <module>
#       1 # Convert to seconds
# ----> 2 df["new_time"] = df["last_update"]/1000
#
# NameError: name 'df' is not defined

# %%
print(datetime.datetime.fromtimestamp(1459511200))

# %%
df['datetime'] = pd.to_datetime(df['new_time'],unit='s')

# %%
x = df["datetime"][0]
print(x.strftime('%H:%M:%S'))

# %%
print(x.strftime('%A'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a549a7d4df15> in <module>
# ----> 1 print(x.strftime('%A'))
#
# NameError: name 'x' is not defined

# %%
df2 = df[["new_time", "datetime"]]

# %%
df2.head()

# %%
f = open("test.txt", "w")
for i in df["datetime"]:
    f.write(str(i)+"\n")
f.close()

# %%
f=open("test2.txt", "r")
data = f.readlines()
f.close()

# %%
df3 = pd.DataFrame(data)
df3.head()

# %%
df["datetime"] = df3[0]
df.head()

# %%
df["datetime"] = df["datetime"].str.replace("\n", "")

# %%
df.head()

# %%
df.replace(to_replace="2016-04-01", value="Friday", inplace=True)

# %%
df_temp = df["time"].str.split(":", expand=True)

# %%
df.head()

# %%
con = sqlite3.connect("test2.db")
cur= con.cursor()
df.to_sql("dBikes", con)

# %%
con.close()
con = sqlite3.connect("test.db")
con.close()

# %%
#create map of Dublin
import folium
map_osm = folium.Map(location=[53.3498, -6.2603], zoom_start=13)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
import requests
stamen = folium.Map(location=[53.343368, -6.270120], tiles='Stamen Toner', zoom_start=14)

r = requests.get('http://api.citybik.es/dublinbikes.json')
data = r.json()

for i in data:
    if (i['free'] > (i['bikes'] *0.4)):  #Green icon if 40% of spots are available.
        x = float(i['lat']/1000000)
        y = float(i['lng']/1000000)
        stamen.simple_marker([x, y], popup=i['name'],marker_color='green')
    else:
        x = float(i['lat']/1000000)
        y = float(i['lng']/1000000)
        stamen.simple_marker([x, y], popup=i['name'],marker_color='red')
stamen
# Out:
# C:\Users\Romain\Anaconda3\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# C:\Users\Romain\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: simple_marker is deprecated. Use add_children(Marker) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
